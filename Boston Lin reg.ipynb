# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
import scipy.stats
# %matplotlib inline

# %% [markdown]
# Importing inbuilt Datasets boston dataset i.e present in sklearn library

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
# df = pd.read_csv(r'C:\\Users\\SHEIKH\\Anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\boston_house_prices.csv')

# %%
df = pd.DataFrame(boston.data , columns = boston.feature_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df.shape
# Out:
# (506, 13)

# %%
#Adding a target column in the dataset

# %%
df['target'] = boston.target

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target'],
#       dtype='object')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# Creating the index

# %%
Index = [i for i in range(1,507)]

# %% [markdown]
# assigning index to the dataframe

# %%
df.set_index(pd.Index(Index))
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 1    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 2    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 3    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 4    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 5    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 502  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 503  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 504  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 505  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 506  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 1       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# Counting the number of Null Values

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %% [markdown]
# Plotting the null values if any in the dataframe

# %%
sns.heatmap(df.isnull())

# %%
#Gives us the description about the dataframe
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Standard deviaton of columns ZN , TAX &  B are higher

# %% [markdown]
# Visualizing the outliers by the use of BoxPlot

# %%
df.plot.box(figsize = (17,9))

# %%
df.plot(kind= 'box', subplots = True , layout = (2,7) , figsize = (16,9))
plt.show()

# %% [markdown]
# A z-score (also called a standard-score) gives you an idea of how far from the mean a data point is.

# %%
# Taking abs(absolute) so that all the values becomes +ve
from scipy.stats import zscore
z_score = np.abs(zscore(df))
z_score
# Out:
# array([[0.41978194, 0.28482986, 1.2879095 , ..., 0.44105193, 1.0755623 ,
#         0.15968566],
#        [0.41733926, 0.48772236, 0.59338101, ..., 0.44105193, 0.49243937,
#         0.10152429],
#        [0.41734159, 0.48772236, 0.59338101, ..., 0.39642699, 1.2087274 ,
#         1.32424667],
#        ...,
#        [0.41344658, 0.48772236, 0.11573841, ..., 0.44105193, 0.98304761,
#         0.14880191],
#        [0.40776407, 0.48772236, 0.11573841, ..., 0.4032249 , 0.86530163,
#         0.0579893 ],
#        [0.41500016, 0.48772236, 0.11573841, ..., 0.44105193, 0.66905833,
#         1.15724782]])

# %%
print(np.where(z_score>3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
#Countnig how much values are 3 standard deviation away from the mean 
np.count_nonzero(z_score > 3)
# Out:
# 100

# %%
z_score[55][1]
# Out:
# 3.375038763517294

# %%
#pyplot. hist(x, alpha=n) with x as a data set and n as an integer between 0 and 1 
#specifying the transparency of each histogram. A lower value of n results in a more transparent histogram.
plt.show(df.plot.hist(bins = 10  , alpha = 1  ))

# %%
df['CRIM'].isnull().sum()
# Out:
# 0

# %%
df['CRIM'].plot.hist()

# %% [markdown]
# Here through the histogram we can see the column ['CRIM'] have very much skewness in the data , so we'll
# take the log of it to remove its skewness.

# %%
from scipy.stats import boxcox 
df['CRIM'] = boxcox(df['CRIM'],0)
print(df['CRIM'])
# Out:
# 0     -5.064036
# 1     -3.600502
# 2     -3.601235
# 3     -3.430523
# 4     -2.672924
#          ...
# 501   -2.770511
# 502   -3.095111
# 503   -2.800824
# 504   -2.211009
# 505   -3.048922
# Name: CRIM, Length: 506, dtype: float64

# %%
df['CRIM'].plot.hist()

# %%
# Another way of doing log transformation 
#df['CRIM'] = np.abs(np.log(df['CRIM']))

# %%
g = sns.pairplot(df )
# g

# %%
#Just plotting ['CRIM'] with target to find the relationship between these two 
sns.scatterplot(df['CRIM'],df['target'],)

# %%
plt.scatter(df['CRIM'],df['target'])

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
corr_heatmap = df.corr()
plt.figure(figsize = (14,7))
sns.heatmap(corr_heatmap , annot = True , cmap = 'YlGnBu_r')

# %%
# Here we can see there's a negative relation b/w 'LSTAT' & 'target
plt.xlabel('target')
plt.ylabel('LSTAT')
plt.scatter(df['target'],df['LSTAT'])
plt.show()

# %%
# Here we can see there's a high positive relation b/w 'RM' & 'target'
plt.xlabel('target')
plt.ylabel('RM')
plt.scatter(df['target'],df['RM'])
plt.show()

# %%
# Dropping 'LSTAT' as it's very much begatively correlational to 'target'
df.drop('LSTAT',axis = 1, inplace = True)
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %% [markdown]
# Grabbing out all the values which has a z_score < 3

# %%
df_new = df[(z_score<3).all(axis = 1)]
df_new
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %%
df = df_new
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %%
x = df.iloc[:,:-1]
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# ...

# %%
y = df.iloc[:,-1]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: target, Length: 415, dtype: float64

# %%
X_train , X_test , y_train , y_test = train_test_split(x , y ,test_size = 33 , random_state = 42)

# %%
X_train.shape
# Out:
# (382, 12)

# %%
X_test.shape
# Out:
# (33, 12)

# %%
y_train.shape
# Out:
# (382,)

# %%
y_test.shape
# Out:
# (33,)

# %%
X_train.size
# Out:
# 4584

# %%
# y_train = np.reshape(383,1)
y_train.size
# Out:
# 382

# %%
#making an instance of linear regression model 
lr = LinearRegression()
a = lr.fit(X_train,y_train)

# %% [markdown]
# In linear regression, coefficients are the values that multiply the predictor values.
# Suppose you have the following regression equation: y = 3X + 5. In this equation, +3 is the coefficient,
# X is the predictor, and +5 is the intercept.

# %%
lr.coef_
# Out:
# array([ 1.39321107e-01, -1.11020578e-02, -1.02477026e-02,  1.41209960e-13,
#        -1.62164422e+01,  7.56330503e+00, -5.95174843e-02, -1.23424936e+00,
#         1.00451437e-01, -1.13414579e-02, -9.56977482e-01,  1.03804416e-02])

# %%
lr.intercept_
# Out:
# 10.22799093719459

# %%
lr.score(X_train , y_train)
# Out:
# 0.7000228210437107

# %%
pred = lr.predict(X_test)
print("Predicted result price : ",pred)
print("Actual price : ", y_test)
# Out:
# Predicted result price :  [20.17038368 14.37364022 31.9554124  18.54836362 13.55223137 20.79482645
#  17.37838256 24.61925006 29.95069861 11.37683022 17.9685298  15.74527988
#   9.44904231 24.74949776 27.91884313 11.34928394 26.51181164 27.07181881
#  25.38914925 14.32492764 21.72382424 19.86877484 24.06045078 12.53252042
#  22.71739278 22.40545132 31.86512023 27.69926652 22.51323886 24.61661544
#  31.7380201  14.38341964 14.29365385]
# Actual price :  58     23.3
# 146    15.6
# 187    32.0
# 59     19.6
# 407    27.9
# 339    19.0
# 468    19.1
# 504    22.0
# 188    29.8
# 389    11.5
# 487    20.6
# 143    15.6
# 362    20.8
# 96     21.4
# 80     28.0
# 477    12.0
# 93     25.0
# 344    31.2
# 185    29.6
# 151    19.6
# 494    24.5
# 9      18.9
# 75     21.4
# 383    12.3
# 76     20.0
# 241    20.1
# 259    30.1
# 85     26.6
# 165    25.0
# 250    24.4
# 291    37.3
# 30     12.7
# 408    17.2
# Name: target, dtype: float64

# %%
print("Error : ")
print('Mean absolute error : ', mean_absolute_error(y_test,pred))
print('Mean squared error : ', mean_squared_error(y_test,pred))
print('Root mean squared error : ', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Error :
# Mean absolute error :  2.6340848593896564
# Mean squared error :  15.90670273726052
# Root mean squared error :  3.9883207916691608

# %%
#r2 score  ------ > Coefficient of determination
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5868980079681223

# %%
t = np.array([-3.048922	,0.0,11.93,	0.0,	0.573,6.030	,80.8	,2.5050	,1.0	,273.0	,21.0	,396.90])
t.shape
# Out:
# (12,)

# %%
# .reshape(1,-1) ----> 1 row many columns
t = t.reshape(1,-1) 
t.shape
# Out:
# (1, 12)

# %%
lr.predict(t)
# Out:
# array([19.12256086])

# %%
t = np.array([2.770511,0.0,11.93,0.0,0.573,6.593,69.1,2.4786,1.0,273.0	,21.0,391.99	])
t = t.reshape(1,-1)

# %%
lr.predict(t)
# Out:
# array([24.86944223])
